# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ![Screenshot 2022-01-19 153224.png](data:image/png;base64,...)![3-s2.0-B9780128154588000074-f07-02-9780128154588.jpg](data:image/jpeg;base64,...)

# %%
def sig(x):
    s=(1/(1+np.exp(-x))) #sigmoid function

    ds=s*(1-s)  #derivative

    return s,ds

# %%
x=np.arange(-6,6,0.01)
print(x)
# Out:
# [-6.   -5.99 -5.98 ...  5.97  5.98  5.99]

# %% [markdown]
# # plotting

# %%
fig,ax= plt.subplots(figsize=(9,5))
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.plot(x,sig(x)[0],color='#307EC7',linewidth=3,label='sigmoid')
ax.plot(x,sig(x)[1],color='#9621E2',linewidth=3,label='derivative')
ax.legend(loc='upper left',frameon=False)
fig.show()
# Out:
# /var/folders/5b/tr5hz8793rgd97llwhztpcpr0000gn/T/ipykernel_4475/3341247443.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Create a figure for the plots
plt.figure(figsize=(9, 5))

# First subplot for the sigmoid function
plt.subplot(1, 2, 1)  # 1 row, 2 columns, first subplot
plt.plot(x, sig(x)[0], color='#307EC7', linewidth=3, label='Sigmoid')
plt.title('Sigmoid Function')
plt.xlabel('x')
plt.ylabel('sigmoid(x)')
plt.axhline(0, color='black',linewidth=0.5, ls='--')  # Horizontal line at y=0
plt.axvline(0, color='black',linewidth=0.5, ls='--')  # Vertical line at x=0
plt.legend()
plt.grid()

# Second subplot for the derivative of the sigmoid function
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
plt.plot(x, sig(x)[1], color='#9621E2', linewidth=3, label='Derivative')
plt.title('Derivative of Sigmoid Function')
plt.xlabel('x')
plt.ylabel("sigmoid'(x)")
plt.axhline(0, color='black',linewidth=0.5, ls='--')  # Horizontal line at y=0
plt.axvline(0, color='black',linewidth=0.5, ls='--')  # Vertical line at x=0
plt.legend()
plt.grid()

# Show the figure with the subplots
plt.tight_layout()  # Adjusts the layout for better spacing
plt.show()
